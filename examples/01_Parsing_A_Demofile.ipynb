# %% [markdown]
# # Parsing Demo Files
# In this Jupyter Notebook, we show how to use the `csgo` package to parse Counter-Strike: Global Offensive demofiles. In many competitive matches, such as those on [HLTV](www.hltv.org), a demofile is kept of all the events that occur on the server during the match. This includes things such as round starts and ends, damages, kills and even finer grained events such as weapon firings and footsteps.

# %%
import sys  
sys.path.insert(0, "..")

import csgo

# %% [markdown]
# Next, we import the `CSGOMatchParser` object. This object is created by providing the demo file (ending in `.dem`) and a log file path as arguments. To instantiate the parser, we can simply call `parser = CSGOMatchParser(demofile = ..., logpath = ...)`.

# %%
from csgo.parser.match_parser import CSGOMatchParser

parser = CSGOMatchParser(demofile = "vitality-vs-natus-vincere-m1-dust2.dem", logfile="parser_log.log")

# %% [markdown]
# To parse the demofile, we conduct three steps.
#
# - (1) We run the `parse_demofile()` method, which parses the demo file using our Go backend. The parsed text is then written to parser.parsed_text. Each event is contained in a "cell", which looks like `[... event info ...]`
# - (2) Then, we find the match start time using `find_match_start()` method. If we get a weird match start, it is likely that the demo file is corrupted in some way, and the match start (found in the `.match_start` attribute) will be 0.
# - (3) Finally, we run `parse_match()`, which loops through the cells in `.parsed_text` and output the data into a collection of lists

# %%
parser.parse_demofile()
parser.find_match_start()
parser.parse_match()

# %% [markdown]
# We currently provide the ability to parse information on the following events:
#
# - Rounds
# - Kills
# - Damages
# - Footsteps
#
# To get this information in Pandas dataframe format, we can use the `write_` methods, as shown below.

# %%
parser.write_footsteps()
parser.write_damages()
parser.write_kills()
parser.write_rounds()

# %% [markdown]
# ## Rounds

# %%
parser.rounds_df.columns
# Out:
# Index(['MatchName', 'MapName', 'RoundNum', 'StartTick', 'EndTick',
#        'EndCTScore', 'EndTScore', 'StartTScore', 'StartCTScore',
#        'RoundWinnerSide', 'RoundWinner', 'RoundLoser', 'Reason'],
#       dtype='object')

# %%
parser.rounds_df
# Out:
#                              MatchName   MapName  RoundNum  StartTick  \
# 0   vitality-vs-natus-vincere-m1-dust2  de_dust2         0          0
# 1   vitality-vs-natus-vincere-m1-dust2  de_dust2         1       9108
# 2   vitality-vs-natus-vincere-m1-dust2  de_dust2         2      16456
# 3   vitality-vs-natus-vincere-m1-dust2  de_dust2         3      34645
# 4   vitality-vs-natus-vincere-m1-dust2  de_dust2         4      50443
# 5   vitality-vs-natus-vincere-m1-dust2  de_dust2         5      72275
# 6   vitality-vs-natus-vincere-m1-dust2  de_dust2         6      96246
# 7   vitality-vs-natus-vincere-m1-dust2  de_dust2         7     110647
# 8   vitality-vs-natus-vincere-m1-dust2  de_dust2         8     128334
# 9   vitality-vs-natus-vincere-m1-dust2  de_dust2         9     140214
# 10  vitality-vs-natus-vincere-m1-dust2  de_dust2        10     161168
# 11  vitality-vs-natus-vincere-m1-dust2  de_dust2        11     176760
# 12  vitality-vs-natus-vincere-m1-dust2  de_dust2        12     196040
# 13  vitality-vs-natus-vincere-m1-dust2  de_dust2        13     212386
# 14  vitality-vs-natus-vincere-m1-dust2  de_dust2        14     228019
# 15  vitality-vs-natus-vincere-m1-dust2  de_dust2        15     259152
# 16  vitality-vs-natus-vincere-m1-dust2  de_dust2        16     269660
# 17  vitality-vs-natus-vincere-m1-dust2  de_dust2        17     280948
# 18  vitality-vs-natus-vincere-m1-dust2  de_dust2        18     295396
# 19  vitality-vs-natus-vincere-m1-dust2  de_dust2        19     306601
#
#     EndTick  EndCTScore  EndTScore  StartTScore  StartCTScore RoundWinnerSide  \
# 0      8467           1          0            0             0              CT
# 1     15815           2          0            0             1              CT
# 2     34005           3          0            0             2              CT
# 3     49803           4          0            0             3              CT
# 4     71635           5          0            0             4              CT
# 5     95606           6          0            0             5              CT
# 6    110007           6          1            0             6               T
# 7    127694           7          1            1             6              CT
# 8    139573           8          1            1             7              CT
# 9    160527           9          1            1             8              CT
# 10   176119           9          2            1             9               T
# 11   195400          10          2            2             9              CT
# 12   211744          11          2            2            10              CT
# 13   227377          12          2            2            11              CT
# 14   237944          13          2            2            12              CT
# 15   269017           3         13            2            13              CT
# 16   280307           4         13           13             3              CT
# 17   294755           4         14           13             4               T
# 18   305959           4         15           14             4               T
# 19   313927           4         16           15             4               T
#
#       RoundWinner     RoundLoser         Reason
# 0   Natus Vincere       Vitality          CTWin
# 1   Natus Vincere       Vitality          CTWin
# 2   Natus Vincere       Vitality    BombDefused
# 3   Natus Vincere       Vitality    BombDefused
# 4   Natus Vincere       Vitality    BombDefused
# 5   Natus Vincere       Vitality    BombDefused
# 6        Vitality  Natus Vincere   TargetBombed
# 7   Natus Vincere       Vitality    BombDefused
# 8   Natus Vincere       Vitality          CTWin
# 9   Natus Vincere       Vitality          CTWin
# 10       Vitality  Natus Vincere  TerroristsWin
# 11  Natus Vincere       Vitality    BombDefused
# 12  Natus Vincere       Vitality          CTWin
# 13  Natus Vincere       Vitality          CTWin
# 14  Natus Vincere       Vitality          CTWin
# 15       Vitality  Natus Vincere          CTWin
# 16       Vitality  Natus Vincere          CTWin
# 17  Natus Vincere       Vitality  TerroristsWin
# 18  Natus Vincere       Vitality  TerroristsWin
# 19  Natus Vincere       Vitality  TerroristsWin

# %% [markdown]
# ## Kills

# %%
parser.kills_df.columns
# Out:
# Index(['MatchName', 'MapName', 'RoundNum', 'Tick', 'VictimX', 'VictimY',
#        'VictimZ', 'VictimViewX', 'VictimViewY', 'VictimAreaID',
#        'VictimAreaName', 'AttackerX', 'AttackerY', 'AttackerZ',
#        'AttackerViewX', 'AttackerViewY', 'AttackerAreaID', 'AttackerAreaName',
#        'VictimID', 'VictimName', 'VictimTeam', 'VictimSide', 'VictimTeamEqVal',
#        'AttackerID', 'AttackerName', 'AttackerTeam', 'AttackerSide',
#        'AttackerTeamEqVal', 'WeaponID', 'IsWallshot', 'IsHeadshot'],
#       dtype='object')

# %%
parser.kills_df
# Out:
#                               MatchName   MapName  RoundNum    Tick  \
# 0    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    2121
# 1    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    2228
# 2    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    4394
# 3    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    5932
# 4    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    5946
# ..                                  ...       ...       ...     ...
# 127  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313367
# 128  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313463
# 129  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313591
# 130  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313720
# 131  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313927
#
#          VictimX      VictimY     VictimZ  VictimViewX  VictimViewY  \
# 0    -397.257477  1490.362549 -126.342102   197.687988   358.599243
# 1    -871.901306  1482.615112 -110.637375   352.315063   352.738037
# 2    1276.026367  1221.711304    0.643850    88.956299   359.500122
# 3     330.556549  2543.625977   97.087769   356.995239     0.137329
# 4    -544.407227  1766.096313 -117.128036    61.045532     4.301147
# ..           ...          ...         ...          ...          ...
# 127  1183.841919  2071.794434    1.340927   341.092529     3.383789
# 128   955.962402  2224.149414    1.755901   324.234009     2.856445
# 129  1243.080078  2786.896484  127.031250   281.321411     8.442993
# 130  1415.130005  1892.677124   -9.212101   136.774292     2.180786
# 131  1303.011353  2086.026367   -1.117817   271.186523     1.054688
#
#      VictimAreaID  ... VictimSide  VictimTeamEqVal         AttackerID  \
# 0            6695  ...         CT             4400  76561198113666193
# 1            1289  ...          T             4250  76561198034202275
# 2            4964  ...          T             4250  76561198146207066
# 3            1723  ...          T             4250  76561198034202275
# 4            5220  ...          T             4250  76561198116523276
# ..            ...  ...        ...              ...                ...
# 127          8668  ...         CT            11250  76561198116523276
# 128          8672  ...         CT            11450  76561198116523276
# 129           755  ...         CT            11450  76561198116523276
# 130          4175  ...          T            26250  76561198006920295
# 131          4201  ...         CT            11450  76561197972331023
#
#      AttackerName   AttackerTeam  AttackerSide  AttackerTeamEqVal WeaponID  \
# 0           ZywOo       Vitality             T               4250    Glock
# 1          s1mple  Natus Vincere            CT               4400      USP
# 2         Boombl4  Natus Vincere            CT               4400      USP
# 3          s1mple  Natus Vincere            CT               4400      USP
# 4          flamie  Natus Vincere            CT               4400      USP
# ..            ...            ...           ...                ...      ...
# 127        flamie  Natus Vincere             T              26250     AK47
# 128        flamie  Natus Vincere             T              26250     AK47
# 129        flamie  Natus Vincere             T              26250     AK47
# 130          shox       Vitality            CT              11450    Famas
# 131      GuardiaN  Natus Vincere             T              26250      AWP
#
#      IsWallshot IsHeadshot
# 0             0          1
# 1             0          1
# 2             0          1
# 3             0          1
# 4             0          1
# ..          ...        ...
# 127           0          0
# 128           0          1
# 129           0          0
# 130           0          0
# 131           0          0
#
# [132 rows x 31 columns]

# %% [markdown]
# ## Damages

# %%
parser.damages_df.columns
# Out:
# Index(['MatchName', 'MapName', 'RoundNum', 'Tick', 'VictimX', 'VictimY',
#        'VictimZ', 'VictimViewX', 'VictimViewY', 'VictimAreaID',
#        'VictimAreaName', 'AttackerX', 'AttackerY', 'AttackerZ',
#        'AttackerViewX', 'AttackerViewY', 'AttackerAreaID', 'AttackerAreaName',
#        'VictimID', 'VictimName', 'VictimTeam', 'VictimSide', 'VictimTeamEqVal',
#        'AttackerID', 'AttackerName', 'AttackerTeam', 'AttackerSide',
#        'AttackerTeamEqVal', 'HpDamage', 'ArmorDamage', 'WeaponID', 'HitGroup'],
#       dtype='object')

# %%
parser.damages_df
# Out:
#                               MatchName   MapName  RoundNum    Tick  \
# 0    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    2121
# 1    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    2228
# 2    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    2423
# 3    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    3430
# 4    vitality-vs-natus-vincere-m1-dust2  de_dust2         0    4372
# ..                                  ...       ...       ...     ...
# 568  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313709
# 569  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313720
# 570  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313913
# 571  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313926
# 572  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313927
#
#          VictimX      VictimY     VictimZ  VictimViewX  VictimViewY  \
# 0    -397.257477  1490.362549 -126.342102   197.687988   358.599243
# 1    -871.901306  1482.615112 -110.637375   352.315063   352.738037
# 2     -25.938940  1371.270752    0.223213   171.595459     9.036255
# 3     352.659943  1582.467773    3.344252   212.964478     0.549316
# 4    1293.380371  1228.092651    1.031250    91.604004     0.000000
# ..           ...          ...         ...          ...          ...
# 568  1415.616943  1893.218994   -9.245815   136.774292     1.455688
# 569  1415.130005  1892.677124   -9.212101   136.774292     2.180786
# 570  1326.287720  1170.067627   -1.081696    93.762817     0.362549
# 571  1326.315186  1169.910034   -1.092643    92.235718     0.208740
# 572  1303.011353  2086.026367   -1.117817   271.186523     1.054688
#
#      VictimAreaID  ... VictimTeamEqVal         AttackerID  AttackerName  \
# 0            6695  ...            4400  76561198113666193         ZywOo
# 1            1289  ...            4250  76561198034202275        s1mple
# 2            8775  ...            4400  76561198006920295          shox
# 3            7555  ...            4400  76561198004871434          ALEX
# 4            4232  ...            4250  76561198146207066       Boombl4
# ..            ...  ...             ...                ...           ...
# 568          4175  ...           26250  76561198006920295          shox
# 569          4175  ...           26250  76561198006920295          shox
# 570          4170  ...           26250  76561198006920295          shox
# 571          4170  ...           26250  76561198006920295          shox
# 572          4201  ...           11450  76561197972331023      GuardiaN
#
#       AttackerTeam  AttackerSide  AttackerTeamEqVal  HpDamage ArmorDamage  \
# 0         Vitality             T               4250       100           0
# 1    Natus Vincere            CT               4400       100           0
# 2         Vitality             T               4250        93           0
# 3         Vitality             T               4250        14           8
# 4    Natus Vincere            CT               4400        28           0
# ..             ...           ...                ...       ...         ...
# 568       Vitality            CT              11450        20           4
# 569       Vitality            CT              11450        25           5
# 570       Vitality            CT              11450        19           4
# 571       Vitality            CT              11450        24           5
# 572  Natus Vincere             T              26250       100           1
#
#      WeaponID HitGroup
# 0       Glock  Generic
# 1         USP  Generic
# 2       Glock  Generic
# 3       Glock    Chest
# 4         USP  LeftArm
# ..        ...      ...
# 568     Famas     Head
# 569     Famas    Chest
# 570     Famas     Head
# 571     Famas    Chest
# 572       AWP  LeftArm
#
# [573 rows x 32 columns]

# %% [markdown]
# ## Footsteps

# %%
parser.footstep_df.columns
# Out:
# Index(['MatchName', 'MapName', 'RoundNum', 'Tick', 'SteamID', 'PlayerName',
#        'Team', 'Side', 'X', 'Y', 'Z', 'ViewX', 'ViewY', 'AreaID', 'AreaName'],
#       dtype='object')

# %%
parser.footstep_df
# Out:
#                                 MatchName   MapName  RoundNum    Tick  \
# 0      vitality-vs-natus-vincere-m1-dust2  de_dust2         0      56
# 1      vitality-vs-natus-vincere-m1-dust2  de_dust2         0      56
# 2      vitality-vs-natus-vincere-m1-dust2  de_dust2         0      56
# 3      vitality-vs-natus-vincere-m1-dust2  de_dust2         0      56
# 4      vitality-vs-natus-vincere-m1-dust2  de_dust2         0      57
# ...                                   ...       ...       ...     ...
# 14054  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313854
# 14055  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313869
# 14056  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313898
# 14057  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313903
# 14058  vitality-vs-natus-vincere-m1-dust2  de_dust2        19  313908
#
#                  SteamID  PlayerName           Team Side            X  \
# 0      76561198034202275      s1mple  Natus Vincere   CT   291.104889
# 1      76561198006920295        shox       Vitality    T -1086.122192
# 2      76561198014251501         RpK       Vitality    T  -760.133118
# 3      76561198116523276      flamie  Natus Vincere   CT    67.778549
# 4      76561198044045107  electronic  Natus Vincere   CT   224.600494
# ...                  ...         ...            ...  ...          ...
# 14054  76561198034202275      s1mple  Natus Vincere    T  1156.201538
# 14055  76561198044045107  electronic  Natus Vincere    T   382.527008
# 14056  76561198006920295        shox       Vitality   CT  1289.039917
# 14057  76561198034202275      s1mple  Natus Vincere    T  1235.246948
# 14058  76561198044045107  electronic  Natus Vincere    T   413.094299
#
#                  Y           Z       ViewX      ViewY  AreaID     AreaName
# 0      2274.387451 -125.846268  350.095825   0.675659    8781    ExtendedA
# 1      -781.127930  118.192795  116.845093   2.988281    8826       TSpawn
# 2      -803.935059  116.703659  165.750732   7.662964    6992       TSpawn
# 3      2121.892090 -126.964630  175.973511   0.384521    1801      CTSpawn
# 4      2420.002686 -120.977119  241.007080   6.822510    8823      CTSpawn
# ...            ...         ...         ...        ...     ...          ...
# 14054  1050.952515   -2.659838   54.212036   4.059448    4167    LongDoors
# 14055  -316.841278    9.031250   68.895264  11.315918    8846  OutsideLong
# 14056  2081.942627   -0.719087  276.855469   1.510620    4201        LongA
# 14057  1063.822021    0.028645   80.859375   1.746826    4167    LongDoors
# 14058  -247.479767   -1.711869   69.867554  10.541382    8846  OutsideLong
#
# [14059 rows x 15 columns]
