# %% [markdown]
# # Parsing a CSGO demofile
# ##### Last Updated: June 12, 2020
#
# The `csgo` package allows for the parsing of CSGO demofiles into the Pandas format, which makes for easy analysis. To install the package, clone the Github repository, navigate to the root directory and run `python setup.py install`. Also, make sure you have installed at least [Go](https://golang.org/) version 1.14.
#
# #### What is a demofile?
# Each CSGO match typically generates recordings of the game called a demofile. Every map in a match will generate its own demofile. This demofile contains a serialization of the data transferred between the host (game server) and its clients (players). Data transferred to and from the server occurs at a predefined _tick rate_, which defines when client inputs are resolved with the server. For professional games, the server tick rate is usually 128 ticks per second, meaning each tick represents around 7.8 milliseconds. Client inputs represent player actions, such as movement, attacks or grenade throws. Non-client events also register in the demofile, such as round starts and ends. For a detailed overview of CSGO demofiles, see [1].
#
# Since CSGO demofiles are essentially data transferred between the clients and the game server, the data is simply stored as a text of sequential set of events with no contextual information, such as round or map location.
# Thus, due to the highly unstructured nature of these low level CSGO data streams, akin to log files, performing any complex analytic tasks becomes impossible without modeling this data formally into a useful data structure. The `csgo` package addresses this need.
#
# #### How do I get demofiles?
# One of the most common ways to obtain demofiles is through the site [HLTV](www.hltv.org). If you navigate to a match page, an hour or so after the match has concluded, it will often contain a link to the demofiles for that match. The link is a `.rar` compressed directory containing a demo for each map in the match.

# %% [markdown]
# # Initializing the parser
# Let's consider the demo from the following [ESL Pro League Season 10 Finals](https://www.hltv.org/matches/2338065/astralis-vs-liquid-esl-pro-league-season-10-finals). If we download the compressed demofile directory (450 MB), there are three files:
#
# - `astralis-vs-liquid-m1-inferno.dem`
# - `astralis-vs-liquid-m2-nuke.dem`
# - `astralis-vs-liquid-m3-dust2.dem`
#
# In order to parse one of the demofiles, you have to instantiate a `DemoParser` object and pass it the path to the demofile, along with a `match_id`. We will use `match_id = "astralis-vs-liquid-m1-inferno.dem"`.

# %%
from csgo.parser import DemoParser

# Create parser object
# Set log=True above if you want to produce a logfile for the parser
demo_parser = DemoParser(demofile = "astralis-vs-liquid-m1-inferno.dem", match_id = "astralis-vs-liquid-m1-inferno.dem")


# Parse the demofile, output results to dictionary with df name as key
data = demo_parser.parse()
# Out:
# 16:17:37 [INFO] Initialized CSGODemoParser with demofile astralis-vs-liquid-m1-inferno.dem
# 16:17:37 [INFO] Starting CSGO Golang demofile parser, reading in /home/peter/Downloads/examples/astralis-vs-liquid-m1-inferno.dem
# 16:17:37 [INFO] Running Golang parser from /home/peter/.pyenv/versions/3.8.3/lib/python3.8/site-packages/csgo-0.1-py3.8.egg/csgo/parser/
# 16:17:53 [INFO] Demofile parsing complete
# 16:17:53 [INFO] Parsing match events
# 16:17:53 [INFO] Parsed round end 1
# 16:17:53 [INFO] Parsed round end official 1
# 16:17:53 [INFO] Parsed round end 2
# 16:17:53 [INFO] Parsed round end official 2
# 16:17:53 [INFO] Parsed round end 3
# 16:17:53 [INFO] Parsed round end official 3
# 16:17:53 [INFO] Parsed round end 4
# 16:17:53 [INFO] Parsed round end official 4
# 16:17:53 [INFO] Parsed round end 5
# 16:17:53 [INFO] Parsed round end official 5
# 16:17:53 [INFO] Parsed round end 6
# 16:17:53 [INFO] Parsed round end official 6
# 16:17:53 [INFO] Parsed round end 7
# 16:17:53 [INFO] Parsed round end official 7
# 16:17:53 [INFO] Parsed round end 8
# 16:17:53 [INFO] Parsed round end official 8
# 16:17:53 [INFO] Parsed round end 9
# 16:17:53 [INFO] Parsed round end official 9
# 16:17:53 [INFO] Parsed round end 10
# 16:17:53 [INFO] Parsed round end official 10
# 16:17:53 [INFO] Parsed round end 11
# 16:17:53 [INFO] Parsed round end official 11
# 16:17:53 [INFO] Parsed round end 12
# 16:17:53 [INFO] Parsed round end official 12
# 16:17:53 [INFO] Parsed round end 13
# 16:17:53 [INFO] Parsed round end official 13
# 16:17:53 [INFO] Parsed round end 14
# 16:17:53 [INFO] Parsed round end official 14
# 16:17:53 [INFO] Parsed round end 15
# 16:17:53 [INFO] Parsed round end official 15
# 16:17:53 [INFO] Parsed round end 16
# 16:17:53 [INFO] Parsed round end official 16
# 16:17:53 [INFO] Parsed round end 17
# 16:17:53 [INFO] Parsed round end official 17
# 16:17:53 [INFO] Parsed round end 18
# 16:17:53 [INFO] Parsed round end official 18
# 16:17:53 [INFO] Parsed round end 19
# 16:17:53 [INFO] Parsed round end official 19
# 16:17:53 [INFO] Parsed round end 20
# 16:17:53 [INFO] Parsed round end official 20
# 16:17:53 [INFO] Parsed round end 21
# 16:17:53 [INFO] Parsed round end official 21
# 16:17:53 [INFO] Parsed round end 22
# 16:17:53 [INFO] Parsed round end official 22
# 16:17:53 [INFO] Parsed round end 23
# 16:17:53 [INFO] Parsed round end official 23
# 16:17:53 [INFO] Parsed round end 24
# 16:17:53 [INFO] Parsed round end official 24
# 16:17:53 [INFO] Parsed round end 25
# 16:17:53 [INFO] Parsed round end official 25
# 16:17:53 [INFO] Parsed round end 26
# 16:17:53 [INFO] Parsed round end official 26
# 16:17:53 [INFO] Parsed round end 27
# 16:17:53 [INFO] Parsed round end official 27
# 16:17:53 [INFO] Parsed round end 28
# 16:17:53 [INFO] Parsed round end official 28
# 16:17:53 [INFO] Parsed round end 29
# 16:17:53 [INFO] Parsed round end official 29
# 16:17:53 [INFO] Parsed round end 30

# %% [markdown]
# ## Accessing the parsed data

# %% [markdown]
# Then, the information from this map will be contained in a series of Pandas dataframes, each referenced by the following keys:

# %%
data.keys()
# Out:
# dict_keys(['Rounds', 'Footsteps', 'Damages', 'Kills', 'BombEvents', 'Grenades'])

# %% [markdown]
# #### Rounds

# %%
data["Rounds"].head(5)
# Out:
#                              MatchId     MapName  RoundNum  StartTick  \
# 0  astralis-vs-liquid-m1-inferno.dem  de_inferno         1       1161
# 1  astralis-vs-liquid-m1-inferno.dem  de_inferno         2      13300
# 2  astralis-vs-liquid-m1-inferno.dem  de_inferno         3      30101
# 3  astralis-vs-liquid-m1-inferno.dem  de_inferno         4      47004
# 4  astralis-vs-liquid-m1-inferno.dem  de_inferno         5      54144
#
#    EndTick  EndCTScore  EndTScore  StartTScore  StartCTScore RoundWinnerSide  \
# 0    13300           0          1            0             0               T
# 1    30101           1          1            1             0              CT
# 2    47004           2          1            1             1              CT
# 3    54144           3          1            1             2              CT
# 4    72667           3          2            1             3               T
#
#    ... RoundLoser        Reason CTCashSpentTotal  CTCashSpentRound  CTEqVal  \
# 0  ...    8370592  TargetBombed             3600              3600     4600
# 1  ...    8370592         CTWin            13050              9450     9450
# 2  ...    8370592         CTWin            23700             10650    28500
# 3  ...    8370592         CTWin            39350             15650    24950
# 4  ...    8370592  TargetBombed            42150              2800    28350
#
#    TCashSpentTotal  TCashSpentRound  TEqVal  CTRoundType TRoundType
# 0             3400             3400    4400       Pistol     Pistol
# 1            21750            18350   21400     Half Buy   Full Buy
# 2            29700             7950    7950     Full Buy        Eco
# 3            30300              600    1200     Full Buy       None
# 4            52000            21700   22700     Full Buy   Full Buy
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Footsteps

# %%
data["Footsteps"].head(5)
# Out:
#                              MatchId     MapName  RoundNum  Tick     Second  \
# 0  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  3766  20.351562
# 1  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  3766  20.351562
# 2  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  3766  20.351562
# 3  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  3767  20.359375
# 4  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  3767  20.359375
#
#             PlayerID PlayerName         Team Side            X            Y  \
# 0  76561198066693739      EliGE  Team Liquid    T -1626.006714   231.920258
# 1  76561198001151695        NAF  Team Liquid    T -1518.342407   363.537506
# 2  76561197983956651     Magisk     Astralis   CT  2426.950684  1946.602295
# 3  76561197995889730      nitr0  Team Liquid    T -1650.953857   662.440674
# 4  76561198004854956    dupreeh     Astralis   CT  2263.013672  1964.852905
#
#             Z        XViz        YViz       ViewX     ViewY  AreaID AreaName  \
# 0  -63.968750   94.080262 -742.465254  302.475586  2.977295       1   TSpawn
# 1  -66.380058  116.052570 -715.604591  271.785278  8.162842       1   TSpawn
# 2  128.031250  921.214425 -392.530144  250.773926  8.574829      91  CTSpawn
# 3  -48.968750   88.989009 -654.603944  295.076294  7.322388    1044   TSpawn
# 4  128.031250  887.757892 -388.805530  245.192871  5.333862      67  CTSpawn
#
#    DistanceBombsiteA  DistanceBombsiteB
# 0                 48                 39
# 1                 48                 39
# 2                 18                 16
# 3                 52                 43
# 4                 19                 15

# %% [markdown]
# ##### Damages

# %%
data["Damages"].head(5)
# Out:
#                              MatchId     MapName  RoundNum  Tick     Second  \
# 0  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  6063  38.296875
# 1  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  6504  41.742188
# 2  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  6524  41.898438
# 3  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  6579  42.328125
# 4  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  6612  42.585938
#
#        VictimX     VictimY     VictimZ  VictimXViz  VictimYViz  ...  \
# 0  1978.013184  173.367020  160.031250  829.594527 -754.414894  ...
# 1  2113.371338  372.447052  160.031250  857.218640 -713.786316  ...
# 2  2117.859131  125.695236  246.534744  858.134517 -764.143829  ...
# 3  2067.031250 -399.005859  256.031250  847.761480 -871.225686  ...
# 4  2268.382812  199.705856  128.736832  888.853635 -749.039621  ...
#
#           AttackerID  AttackerName  AttackerTeam AttackerSide  \
# 0  76561197999004010      Stewie2K   Team Liquid            T
# 1  76561198066693739         EliGE   Team Liquid            T
# 2  76561197983956651        Magisk      Astralis           CT
# 3  76561197999004010      Stewie2K   Team Liquid            T
# 4  76561197983956651        Magisk      Astralis           CT
#
#    AttackerTeamEqVal  HpDamage  KillHpDamage  ArmorDamage  WeaponID  HitGroup
# 0               4400        12            12            6     Glock      Head
# 1               4400        11            11            6     Glock      Head
# 2               4600        20            20            9       USP     Chest
# 3               4400        11            11            6     Glock   Stomach
# 4               4600        15            15            7       USP      Head
#
# [5 rows x 38 columns]

# %% [markdown]
# ##### Kills

# %%
data["Kills"].head(5)
# Out:
#                              MatchId     MapName  RoundNum   Tick     Second  \
# 0  astralis-vs-liquid-m1-inferno.dem  de_inferno         1   6629  42.718750
# 1  astralis-vs-liquid-m1-inferno.dem  de_inferno         1   6702  43.289062
# 2  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  10756  74.960938
# 3  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  12021  84.843750
# 4  astralis-vs-liquid-m1-inferno.dem  de_inferno         2  19776  50.593750
#
#        VictimX      VictimY     VictimZ  VictimXViz  VictimYViz  ...  \
# 0  2070.210938  -400.019836  255.738281  848.410395 -871.432620  ...
# 1  2236.474121   358.814270  134.983994  882.341657 -716.568516  ...
# 2  2550.814209  1377.042847  160.031250  946.492696 -508.766766  ...
# 3  -349.312500  -305.413849  192.031250  354.630102 -852.125275  ...
# 4    64.399773  1463.703857  176.031250  439.061178 -491.080845  ...
#
#    AttackerSide  AttackerTeamEqVal         AssisterID AssisterName  \
# 0             T               4400                  0           NA
# 1             T               4400                  0           NA
# 2             T               4400  76561198016255205      Twistzz
# 3             T               3750                  0           NA
# 4            CT               9950                  0           NA
#
#    AssisterTeam  AssisterSide  WeaponID  IsWallshot  IsFlashed  IsHeadshot
# 0            NA            NA     Glock           0          0           1
# 1            NA            NA     Glock           0          0           1
# 2   Team Liquid             T       USP           0          0           1
# 3            NA            NA     Glock           0          0           1
# 4            NA            NA    Deagle           0          0           0
#
# [5 rows x 41 columns]

# %% [markdown]
# ##### Bomb Events

# %%
data["BombEvents"].head(5)
# Out:
#                              MatchId     MapName  RoundNum    Tick     Second  \
# 0  astralis-vs-liquid-m1-inferno.dem  de_inferno         1    7411  48.828125
# 1  astralis-vs-liquid-m1-inferno.dem  de_inferno         5   66780  98.718750
# 2  astralis-vs-liquid-m1-inferno.dem  de_inferno         7  102976  96.789062
# 3  astralis-vs-liquid-m1-inferno.dem  de_inferno         9  135050  64.570312
# 4  astralis-vs-liquid-m1-inferno.dem  de_inferno        10  149050  63.359375
#
#             PlayerID PlayerName         Team  AreaID BombSite EventType
# 0  76561198016255205    Twistzz  Team Liquid     157        A     Plant
# 1  76561198066693739      EliGE  Team Liquid    2086        B     Plant
# 2  76561198001151695        NAF  Team Liquid     829        B     Plant
# 3  76561198001151695        NAF  Team Liquid     157        A     Plant
# 4  76561198066693739      EliGE  Team Liquid     157        A     Plant

# %% [markdown]
# ##### Grenades

# %%
data["Grenades"].head(5)
# Out:
#                              MatchId     MapName  RoundNum  Tick     Second  \
# 0  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  4982  29.851562
# 1  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  5225  31.750000
# 2  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  5237  31.843750
# 3  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  5770  36.007812
# 4  astralis-vs-liquid-m1-inferno.dem  de_inferno         1  5922  37.195312
#
#             PlayerID PlayerName         Team Side            X            Y  \
# 0  76561197995889730      nitr0  Team Liquid    T   995.819031   461.206726
# 1  76561198010511021     gla1ve     Astralis   CT   373.511475  2258.871826
# 2  76561197999004010   Stewie2K  Team Liquid    T   874.956848    16.081377
# 3  76561197995889730      nitr0  Team Liquid    T  1428.454956   484.867035
# 4  76561197995889730      nitr0  Team Liquid    T  2295.472168   723.563904
#
#             Z        XViz        YViz  AreaID   AreaName GrenadeType
# 0  205.201797  629.146741 -695.672097      21     Middle       Flash
# 1  383.608948  502.145199 -328.801668    1933  BombsiteB       Flash
# 2   94.751358  604.480989 -786.514005     479  SecondMid       Decoy
# 3  259.739105  717.439787 -690.843462      31   TopofMid       Flash
# 4  148.717834  894.382075 -642.129816      69  BombsiteA       Smoke

# %% [markdown]
# ## References
# [1] Bednárek, David, et al. "Player Performance Evaluation in Team-Based First-Person Shooter eSport." International Conference on Data Management Technologies and Applications. Springer, Cham, 2017.
