# %% [markdown]
# # Basic CSGO Analysis
# ##### *Last Updated: April 6, 2022*
# The awpy package was developed with easy analysis in mind. To start, a user must first parse the demofile, which gives information on player actions ([Parsing a CSGO demofile](https://github.com/pnxenopoulos/awpy/blob/master/examples/00_Parsing_a_CSGO_Demofile.ipynb)). However, we often want to calculate statistics for a player or team from a demofile. Thus, we provide the `awpy.analytics.stats` module.
#
#
# Below, we reference the [demofile](https://www.hltv.org/matches/2337844/astralis-vs-liquid-blast-pro-series-global-final-2019) for a match between Astralis and Team Liquid, where we look at the second map of the series, `de_nuke`.

# %%
from awpy.parser import DemoParser

# Create the parser object.
parser = DemoParser(
    demofile = "astralis-vs-liquid-m2-nuke.dem", 
    demo_id = "AST-TL-BLAST2019-nuke", 
    parse_frames=False, 
)
# Parse the demofile, output results to a dictionary of dataframes.
data = parser.parse()
# Out:
# 23:02:36 [INFO] Initialized CSGODemoParser with demofile /home/peter/Downloads/astralis-vs-liquid-m2-nuke.dem
# 23:02:36 [INFO] Setting demo id to AST-TL-BLAST2019-nuke
# 23:02:36 [INFO] Setting parse rate to 128
# 23:02:36 [INFO] Setting trade time to 5
# 23:02:36 [INFO] Setting buy style to hltv
# 23:02:36 [INFO] Rollup damages set to False
# 23:02:36 [INFO] Parse frames set to False
# 23:02:36 [INFO] Output json indentation set to False
# 23:02:36 [INFO] Go version>=1.14.0
# 23:02:36 [INFO] Running Golang parser from /home/peter/.pyenv/versions/3.8.4/lib/python3.8/site-packages/awpy-1.0.1-py3.8.egg/awpy/parser/
# 23:02:36 [INFO] Looking for file at /home/peter/Downloads/astralis-vs-liquid-m2-nuke.dem
# 23:02:43 [INFO] Wrote demo parse output to AST-TL-BLAST2019-nuke.json
# 23:02:43 [INFO] JSON data loaded, available in the `json` attribute to parser
# 23:02:43 [WARNING] parse_frames is set to False, must be true for remove_no_frames to work. Skipping remove_no_frames.
# 23:02:43 [WARNING] parse_frames is set to False, must be true for remove_excess_players to work. Skipping remove_excess_players.
# 23:02:43 [INFO] JSON output found

# %% [markdown]
# # `player_stats`
#
# `player_stats(game_rounds, return_type="json")` is the base stats function. Given a list of rounds, it calculates each player's statistics, such as kills, ADR, KAST%, and Rating, to name a few.

# %%
from awpy.analytics.stats import player_stats

player_stats_json = player_stats(data["gameRounds"])
player_stats_json[76561197999004010]
# Out:
# {'steamID': 76561197999004010,
#  'playerName': 'Stewie2K',
#  'teamName': 'Team Liquid',
#  'totalRounds': 28,
#  'kills': 17,
#  'deaths': 20,
#  'kdr': 0.85,
#  'assists': 6,
#  'tradeKills': 1,
#  'teamKills': 0,
#  'suicides': 0,
#  'flashAssists': 0,
#  'totalDamageGiven': 2326,
#  'totalDamageTaken': 2118,
#  'totalTeamDamageGiven': 0,
#  'adr': 83.1,
#  'totalShots': 284,
#  'shotsHit': 61,
#  'accuracy': 0.21,
#  'rating': 0.96,
#  'kast': 64.3,
#  'hs': 10,
#  'hsPercent': 0.59,
#  'firstKills': 2,
#  'firstDeaths': 3,
#  'utilityDamage': 121,
#  'smokesThrown': 17,
#  'flashesThrown': 7,
#  'heThrown': 6,
#  'fireThrown': 12,
#  'enemiesFlashed': 7,
#  'teammatesFlashed': 2,
#  'blindTime': 15.86,
#  'plants': 2,
#  'defuses': 0}

# %%
from awpy.analytics.stats import player_stats

player_stats_df = player_stats(data["gameRounds"], return_type="df")
player_stats_df
# Out:
#              steamID playerName     teamName  totalRounds  kills  deaths  \
# 0  76561197999004010   Stewie2K  Team Liquid           28     17      20
# 1  76561198016255205    Twistzz  Team Liquid           28     14      19
# 2  76561197995889730      nitr0  Team Liquid           28     19      17
# 3  76561198001151695        NAF  Team Liquid           28     17      19
# 4  76561198066693739      EliGE  Team Liquid           28     18      21
# 5  76561197987713664     device     Astralis           28     23      17
# 6  76561197990682262      Xyp9x     Astralis           28     22      16
# 7  76561198010511021     gla1ve     Astralis           28     17      16
# 8  76561198004854956    dupreeh     Astralis           28     17      16
# 9  76561197983956651     Magisk     Astralis           28     16      19
#
#     kdr  assists  tradeKills  teamKills  ...  utilityDamage  smokesThrown  \
# 0  0.85        6           1          0  ...            121            17
# 1  0.74        2           0          1  ...             29            16
# 2  1.12        1           3          0  ...             83            16
# 3  0.89        0           2          0  ...             76            11
# 4  0.86        3           3          0  ...            119            14
# 5  1.35        2           5          0  ...            166            12
# 6  1.38        3           1          0  ...            155            17
# 7  1.06        8           2          0  ...            177            21
# 8  1.06        1           3          0  ...             69            16
# 9  0.84        5           2          0  ...            125            16
#
#    flashesThrown  heThrown  fireThrown  enemiesFlashed  teammatesFlashed  \
# 0              7         6          12               7                 2
# 1             11        11          18              10                13
# 2             12         7          11               8                 6
# 3              6        11          10               7                 5
# 4              6        13          13               3                 4
# 5             14         7          14              13                 8
# 6             19        16          18              17                 9
# 7             19        12          11              19                 8
# 8             12         6          13              14                19
# 9             15        16          16              16                22
#
#    blindTime  plants  defuses
# 0      15.86       2        0
# 1      13.99       2        0
# 2      14.27       1        1
# 3       8.22       2        0
# 4      12.82       1        0
# 5      43.22       0        1
# 6      42.75       1        2
# 7      45.63       2        0
# 8      22.73       2        1
# 9      44.11       3        0
#
# [10 rows x 35 columns]
